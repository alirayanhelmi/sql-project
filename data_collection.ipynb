# %%
import requests
import json
import pandas as pd
from sqlalchemy import create_engine

# %%
api_key = 'BpjH4zMrUatPZ00qPPzNgBETNwFB5G4BOkwwzQhcrBRTVW_yz9GYvLHMphOPPiDkoLy7Tqhc2pygki7UfQgj4Tvj0vp1ojPO2MCxKGJ11QpIQ3wTzTq9Hey6GzNDXnYx'
headers = {'Authorization' : 'Bearer %s' % api_key}

businesses_api_url = 'https://api.yelp.com/v3/businesses/search'
params = {'term':'entertainers', 'location':'90024'}

businesses_request = requests.get(businesses_api_url, params=params, headers=headers)

# %%
businesses_request
# Out:
# <Response [200]>

# %%
businesses_request.text
# Out:
# '{"businesses": [{"id": "htp5Vx5GeEU0Sp036Jhs1g", "alias": "dreamscape-los-angeles", "name": "Dreamscape", "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/ND3GzkSzrC3qg7LEggMtvA/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/dreamscape-los-angeles?adjust_creative=cx8d1acAwK5wnNN83apJkw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cx8d1acAwK5wnNN83apJkw", "review_count": 208, "categories": [{"alias": "virtualrealitycenters", "title": "Virtual Reality Centers"}], "rating": 4.5, "coordinates": {"latitude": 34.059019, "longitude": -118.418865837157}, "transactions": [], "location": {"address1": "10250 Santa Monica Blvd", "address2": "Fl 2", "address3": null, "city": "Los Angeles", "zip_code": "90067", "country": "US", "state": "CA", "display_address": ["10250 Santa Monica Blvd", "Fl 2", "Los Angeles, CA 90067"]}, "phone": "+14246032948", "display_phone": "(424) 603-2948", "distance": 1750.5581156654223}, {"id": "uiBW5zdeCrtsJwFy8WvwqQ", "alias
# ...

# %%
decoded_businesses_request_text = json.loads(businesses_request.text)

# %%
decoded_businesses_request_text['businesses']
# Out:
# [{'id': 'htp5Vx5GeEU0Sp036Jhs1g',
#   'alias': 'dreamscape-los-angeles',
#   'name': 'Dreamscape',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ND3GzkSzrC3qg7LEggMtvA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/dreamscape-los-angeles?adjust_creative=cx8d1acAwK5wnNN83apJkw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cx8d1acAwK5wnNN83apJkw',
#   'review_count': 208,
#   'categories': [{'alias': 'virtualrealitycenters',
#     'title': 'Virtual Reality Centers'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 34.059019, 'longitude': -118.418865837157},
#   'transactions': [],
#   'location': {'address1': '10250 Santa Monica Blvd',
#    'address2': 'Fl 2',
#    'address3': None,
#    'city': 'Los Angeles',
#    'zip_code': '90067',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['10250 Santa Monica Blvd',
#     'Fl 2',
#     'Los Angeles, CA 90067']},
#   'phone': '+14246032948',
# ...

# %%
businesses = decoded_businesses_request_text['businesses']

# %%
type(businesses)
# Out:
# list

# %%
business_data = {
    
    'name':[],
    'rating':[],
    'address1':[],
    'address2':[],
    'city':[],
    'state':[],
    'zip_code':[],
    'url':[],
    'id':[]
    
} 

for business in businesses:
    
    name = business['name']
    business_data['name'].append(name)
    print(name) 
            
    rating = business['rating']
    business_data['rating'].append(rating)
    print(rating)
    
    address1 = business['location']['address1']
    business_data['address1'].append(address1)
    print(address1)
    
    address2 = business['location']['address2']
    business_data['address2'].append(address2)
    print(address2)
    
    city = business['location']['city']
    business_data['city'].append(city)
    print(city)
    
    state = business['location']['state']
    business_data['state'].append(state)
    print(state)
    
    zip_code = business['location']['zip_code']
    business_data['zip_code'].append(zip_code)
    print(zip_code)
    
    url = business['url']
    business_data['url'].append(url)
    print(url)
    
    id = business['id']
    business_data['id'].append(id)
    print(id)
    
    print('---------------------------------------')
# Out:
# Dreamscape
# 4.5
# 10250 Santa Monica Blvd
# Fl 2
# Los Angeles
# CA
# 90067
# https://www.yelp.com/biz/dreamscape-los-angeles?adjust_creative=cx8d1acAwK5wnNN83apJkw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cx8d1acAwK5wnNN83apJkw
# htp5Vx5GeEU0Sp036Jhs1g
# ---------------------------------------
# Party People Events
# 3.0
#
#
# Los Angeles
# CA
# 90024
# https://www.yelp.com/biz/party-people-events-los-angeles-2?adjust_creative=cx8d1acAwK5wnNN83apJkw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cx8d1acAwK5wnNN83apJkw
# uiBW5zdeCrtsJwFy8WvwqQ
# ---------------------------------------
# Magic Game Bus
# 5.0
# None
# None
# Los Angeles
# CA
# 90049
# https://www.yelp.com/biz/magic-game-bus-los-angeles?adjust_creative=cx8d1acAwK5wnNN83apJkw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=cx8d1acAwK5wnNN83apJkw
# KUs9SBKg30VsPGBVhBbkeA
# ---------------------------------------
# Domo Entertainment
# 5.0
# ...

# %%
business_data
# Out:
# {'name': ['Dreamscape',
#   'Party People Events',
#   'Magic Game Bus',
#   'Domo Entertainment',
#   'Rainbow Painted Smiles',
#   'Manny Silverman Gallery',
#   'Fox Studio Lot',
#   'Happy Moments',
#   'Face Painting Los Angeles',
#   'DJ Cynful',
#   'Los Virtuality - Virtual Reality Gaming Center',
#   "Nude Paint n' Sip",
#   'Allen Gittelson - Los Angeles Mentalist',
#   'Budget Birthdays',
#   'W Los Angeles - West Beverly Hills',
#   "Keith & Margo's Murder Mystery",
#   "Micah's Magic",
#   'Glorya Kaufman Hall',
#   'Ivan Amodei',
#   'Extra Photo Booths'],
#  'rating': [4.5,
#   3.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   4.0,
#   4.5,
#   5.0,
#   5.0,
#   4.5,
#   4.5,
#   5.0,
#   4.5,
#   3.5,
#   4.0,
#   5.0,
#   4.5,
#   4.0,
#   1.0],
#  'address1': ['10250 Santa Monica Blvd',
#   '',
#   None,
#   '468 N Camden Dr',
#   None,
#   '619 N Almont Dr',
#   '10201 W Pico Blvd',
#   '',
#   '11333 Moorpark St',
#   None,
#   '11901 Santa Monica Blvd',
# ...

# %%
df = pd.DataFrame(business_data)

# %%
df.head()
# Out:
#                      name  rating                 address1 address2  \
# 0              Dreamscape     4.5  10250 Santa Monica Blvd     Fl 2
# 1     Party People Events     3.0
# 2          Magic Game Bus     5.0                     None     None
# 3      Domo Entertainment     5.0          468 N Camden Dr
# 4  Rainbow Painted Smiles     5.0                     None     None
#
#             city state zip_code  \
# 0    Los Angeles    CA    90067
# 1    Los Angeles    CA    90024
# 2    Los Angeles    CA    90049
# 3  Beverly Hills    CA    90210
# 4   Santa Monica    CA    90024
#
#                                                  url                      id
# 0  https://www.yelp.com/biz/dreamscape-los-angele...  htp5Vx5GeEU0Sp036Jhs1g
# 1  https://www.yelp.com/biz/party-people-events-l...  uiBW5zdeCrtsJwFy8WvwqQ
# 2  https://www.yelp.com/biz/magic-game-bus-los-an...  KUs9SBKg30VsPGBVhBbkeA
# 3  https://www.yelp.com/biz/domo-entertainment-be...  sh6G-tz2gsMRM4mADtE5fQ
# ...

# %%
df.to_csv('entertainers_90024.csv', index=False)

# %%
#engine = create_engine('mysql+mysqldb://alirayan_dba:capstone_2020@alirayanhelmi.lmu.build/alirayan_yelp')

# %%
#df.to_sql('business', engine, if_exists='replace')
